# %%
import pandas as pd

# %%
book_5_df = pd.read_csv("datasets/deribit_book_snapshot_5_2021-12-07_BTC-31DEC21-48000-C.csv.gz", compression='gzip', header=0, sep=',')
book_5_df.head(10)
# Out:
#   exchange               symbol         timestamp   local_timestamp  \
# 0  deribit  BTC-31DEC21-48000-C  1638835198750000  1638835200279990
# 1  deribit  BTC-31DEC21-48000-C  1638835206423000  1638835206432862
# 2  deribit  BTC-31DEC21-48000-C  1638835207069000  1638835207074796
# 3  deribit  BTC-31DEC21-48000-C  1638835217664000  1638835217675376
# 4  deribit  BTC-31DEC21-48000-C  1638835217931000  1638835217942213
# 5  deribit  BTC-31DEC21-48000-C  1638835219974000  1638835220068241
# 6  deribit  BTC-31DEC21-48000-C  1638835220135000  1638835220269302
# 7  deribit  BTC-31DEC21-48000-C  1638835220300000  1638835220417972
# 8  deribit  BTC-31DEC21-48000-C  1638835221673000  1638835221763333
# 9  deribit  BTC-31DEC21-48000-C  1638835221977000  1638835222064615
#
#    asks[0].price  asks[0].amount  bids[0].price  bids[0].amount  \
# 0          0.114            10.3         0.1115             8.8
# 1          0.114            10.3         0.1115             8.8
# ...

# %%
bitstamp_1h = pd.read_csv("datasets/Bitstamp_BTCUSD_1h.csv", header=1, sep=',')

# %%
bitstamp_2021_1m = pd.read_csv("datasets/Bitstamp_BTCUSD_2021_minute.csv", header=1, sep=',')

# %%
quotes_jan22_df = pd.read_csv("datasets/deribit_quotes_2021-12-07_BTC-28JAN22-48000-C.csv.gz",compression='gzip', header=0, sep=',')

# %%
trades_sep22_df = pd.read_csv("datasets/deribit_trades_2021-12-07_BTC-30SEP22-70000-C.csv.gz",compression='gzip', header=0, sep=',')

# %%
trades_10dec21_df = pd.read_csv("datasets/deribit_trades_2021-12-08_BTC-10DEC21-50000-P.csv.gz",compression='gzip', header=0, sep=',')
